# %%
import turtle

t=turtle.Turtle()
t.shape('turtle')

#t.hideturtle()

t.penup()
t.backward(200)
t.pendown()

t.color('black')
t.fillcolor('white')
t.begin_fill()
t.forward(400)
t.left(90)
t.forward(200)
t.left(90)
t.forward(400)
t.left(90)
t.forward(200)
t.end_fill()

t.penup()
t.left(90)
t.forward(250)
t.left(90)
t.forward(100)
t.pendown()

t.color('blue')
t.fillcolor('blue')
t.begin_fill()
t.circle(50)
t.end_fill()

t.color('red')
t.fillcolor('red')
t.begin_fill()
t.circle(50,180)
t.circle(25,180)
t.right(90)
t.penup()
t.forward(50)
t.pendown()
t.left(90)
t.circle(25,180)
t.end_fill()

#Fill đoạn màu đỏ vẽ thừa
t.color('blue')
t.fillcolor('blue')
t.begin_fill()
t.circle(25)
t.end_fill()

t.color('black')
#Cumj 1
t.penup()
t.right(90)
t.forward(70)
t.right(90)
t.forward(20)
t.right(45)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.left(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.left(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()


#Cumj 2
t.penup()
t.forward(20)
t.right(45)
t.forward(40)
t.left(45)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.right(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.right(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.forward(10)
t.right(90)
t.forward(32.5)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.end_fill()

#Cumj 3
t.color('black')
t.penup()
t.left(90)
t.forward(32.5)
t.right(90)
t.forward(10)
t.right(45)
t.forward(140)
t.right(135)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.left(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.left(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.left(90)
t.forward(5)
t.left(90)
t.forward(70)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.left(90)
t.forward(32.5)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.forward(10)
t.left(90)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.end_fill()

t.penup()
t.forward(10)
t.left(90)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.left(90)
t.forward(5)
t.end_fill()

#Cumj 4
t.color('black')
t.penup()
t.right(90)
t.forward(32.5)
t.left(45)
t.forward(40)
t.left(45)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.right(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.backward(10)
t.right(90)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.forward(70)
t.right(90)
t.forward(5)
t.right(90)
t.forward(70)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.right(90)
t.forward(32.5)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.end_fill()

t.penup()
t.forward(20)
t.right(90)
t.pendown()

t.color('white')
t.fillcolor('white')
t.begin_fill()
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.right(90)
t.forward(5)
t.end_fill()

t.hideturtle()
#end
turtle.done()
